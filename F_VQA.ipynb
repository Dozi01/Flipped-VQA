# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content/drive/MyDrive/Projects/Flipped-VQA
# !mkdir pretrained
# !mkdir data
# !conda create -n flipped-vqa python=3.8
# !conda activate flipped-vqa
# !sh setup.sh
# Out:
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# sh: 0: cannot open setup.sh: No such file

# %%
ls
# Out:
# asset/        data/        engine.py  F_VQA.ipynb  llama/        pretrained/  setup.sh  util/
# checkpoints@  dataloader/  eval.py    LICENSE      llama_vqa.py  README.md    train.py

# %%
cd data
# Out:
# /content/drive/MyDrive/Projects/Flipped-VQA/data

# %%
ls
# Out:
# data@

# %%
cd data@
